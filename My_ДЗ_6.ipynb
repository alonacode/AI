# %% [markdown]
# <a href="https://colab.research.google.com/github/alonacode/AI/blob/main/My_%D0%94%D0%97_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# [Опис даних](https://search.r-project.org/CRAN/refmans/PPtreeregViz/html/insurance.html)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/insurance.csv")
df = df.select_dtypes('number')

# %%
df.head()
# Out:
#    age   bmi  children  expenses
# 0   19  27.9         0  16884.92
# 1   18  33.8         1   1725.55
# 2   28  33.0         3   4449.46
# 3   33  22.7         0  21984.47
# 4   32  28.9         0   3866.86

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики та кількість пропущених значень по стовпчиках

# %%
df.shape
# Out:
# (1338, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   bmi       1338 non-null   float64
#  2   children  1338 non-null   int64
#  3   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 41.9 KB

# %%
summary_stats = df.describe()
missing_values = df.isnull().sum()

summary_stats, missing_values
# Out:
# (               age          bmi     children      expenses
#  count  1338.000000  1338.000000  1338.000000   1338.000000
#  mean     39.207025    30.665471     1.094918  13270.422414
#  std      14.049960     6.098382     1.205493  12110.011240
#  min      18.000000    16.000000     0.000000   1121.870000
#  25%      27.000000    26.300000     0.000000   4740.287500
#  50%      39.000000    30.400000     1.000000   9382.030000
#  75%      51.000000    34.700000     2.000000  16639.915000
#  max      64.000000    53.100000     5.000000  63770.430000,
#  age         0
#  bmi         0
#  children    0
#  expenses    0
#  dtype: int64)

# %% [markdown]
# # Завдання 2
# Розділіть дані на залежну y(`expenses`) та незалежну X ознаки. Розділіть дані на тренувальну та тестову частини

# %%
X = df.drop('expenses', axis=1)
y = df['expenses']

# Розділяємо дані на тренувальну та тестову частини (80% тренувальні, 20% тестові)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.8,  # частка даних для навчання
                                                    random_state=42) # зерно для генератора випадкових чисел

# %%
X_train, X_test, y_train, y_test
# Out:
# (      age   bmi  children
#  560    46  20.0         2
#  1285   47  24.3         0
#  1142   52  24.9         0
#  969    39  34.3         5
#  486    54  21.5         3
#  ...   ...   ...       ...
#  1095   18  31.4         4
#  1130   39  23.9         5
#  1294   58  25.2         0
#  860    37  47.6         2
#  1126   55  29.9         0
#
#  [1070 rows x 3 columns],
#        age   bmi  children
#  764    45  25.2         2
#  887    36  30.0         0
#  890    64  26.9         0
#  1293   46  25.7         3
#  259    19  31.9         0
#  ...   ...   ...       ...
#  109    63  35.1         0
#  575    58  27.2         0
#  535    38  28.0         1
#  543    54  47.4         0
#  846    51  34.2         1
#
#  [268 rows x 3 columns],
#  560      9193.84
#  1285     8534.67
#  1142    27117.99
#  969      8596.83
#  486     12475.35
#            ...
#  1095     4561.19
#  1130     8582.30
#  1294    11931.13
#  860     46113.51
#  1126    10214.64
# ...

# %% [markdown]
# # Завдання 3
# Натренуйте модель та виведіть такі метрики: MAE, RMSE, R2

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

def get_metrics(y_true, y_pred, name="model"):
  df = pd.DataFrame()

  df.loc["MAE", name] = metrics.mean_absolute_error(y_true, y_pred)
  df.loc["RMSE", name] = metrics.mean_squared_error(y_true, y_pred) ** 0.5
  df.loc["R2", name] = metrics.r2_score(y_true, y_pred)

  return df.round(2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
all_metrics = pd.DataFrame()

all_metrics["train"] = get_metrics(y_train, model.predict(X_train))
all_metrics["test"] = get_metrics(y_test, y_pred)

# %%
all_metrics
# Out:
#       train without intercept  test without intercept
# MAE                   9005.73                 9181.19
# RMSE                 11334.22                11453.76
# R2                       0.11                    0.15

# %% [markdown]
# # Завдання 4
# Напишіть рівняння регресії за прикладом:
# Ціна = 1.02*Температура - 15.6

# %%
model.intercept_
# Out:
# -6131.421933141168

# %%
model.coef_
# Out:
# array([220.72663858, 332.6473806 , 563.40009115])

# %%
b0 = model.intercept_  # це вільний член
b1, b2, b3 = model.coef_  # це коефіцієнти для змінних Age, BMI, Children

Expenses = b0 + b1 * df['age'] + b2 * df['bmi'] + b3 * df['children']

Expenses
# Out:
# 0        7343.246119
# 1        9648.539117
# 2       12716.487780
# 3        8703.652680
# 4       10545.339801
#             ...
# 1333    16907.179068
# 1334     8453.109002
# 1335    10116.345905
# 1336     7086.139896
# 1337    17012.941796
# Length: 1338, dtype: float64

# %% [markdown]
# # Завдання 5 (оптимально)
# Перевірте як видалення викидів вплине на результат. Розгляньте один з варіантів:
# * видалення викидів по стовпчику `expenses`
# * видалення викидів по всіх стовпчиків

# %%
numeric_cols = df.select_dtypes(include=['number'])

# Обчислення квартилів і IQR для числових стовпців
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

# Межі для викидів
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Виявлення викидів у числових стовпцях
outliers = (numeric_cols < lower_bound) | (numeric_cols > upper_bound)

# Виведення кількості викидів у кожній колонці
print(outliers.sum())

# Виведення рядків з викидами
df_outliers = df[outliers.any(axis=1)]
df_outliers
# Out:
# age           0
# bmi           9
# children      0
# expenses    139
# dtype: int64
#       age   bmi  children  expenses
# 14     27  42.1         0  39611.76
# 19     30  35.3         0  36837.47
# 23     34  31.9         1  37701.88
# 29     31  36.3         2  38711.00
# 30     22  35.6         0  35585.58
# ...   ...   ...       ...       ...
# 1301   62  30.9         3  46718.16
# 1303   43  27.8         0  37829.72
# 1313   19  34.7         2  36397.58
# 1317   18  53.1         0   1163.46
# 1323   42  40.4         2  43896.38
#
# [145 rows x 4 columns]

# %%
df_cleaned = df[~outliers.any(axis=1)]

# Виведення розміру нового DataFrame
print(df_cleaned.shape)
# Out:
# (1193, 4)
