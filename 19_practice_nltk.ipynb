# %% [markdown]
# <a href="https://colab.research.google.com/github/alonacode/AI/blob/main/19_practice_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1
# Проведіть токенизацію тексту:
#  * Розділіть текст на речення
#  * Кожне речення розділіть на слова. Результатом має бути `list[list]` де скажімо `data[5][10]` означає 10-те слово з 5-го речення(індексація з 0)
#  * Видаліть пунктуацію та стоп-слова
#  * Створіть список усіх слів з тексту 'words`

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """Mrs Pig was very tired: 'Oh dear,' she said to her three little pigs, 'I can’t do this work anymore, I’m afraid you must leave home and make your own way in the world.' So the three little pigs set off.

The first little pig met a man carrying a bundle of straw.

'Excuse me,' said the first little pig politely. 'Would you please sell some of your straw so I can make a house?'

The man readily agreed and the first little pig went off to find a good place to build his house.

The other little pigs carried on along the road and, soon, they met a man carrying a bundle of sticks.

'Excuse me,' said the little pig politely. 'Would you please sell me some sticks so I can build a house?'

The man readily agreed and the little pig said goodbye to his brother.

The third little pig didn’t think much of their ideas:

'I’m going to build myself a much bigger, better, stronger house,' he thought, and he carried off down the road until he met a man with a cart load of bricks.

'Excuse me,' said the third little pig, as politely as his mother had taught him. 'Please can you sell me some bricks so I can build a house?'

'Of course,' said the man. 'Where would you like me to unload them?'

The third little pig looked around and saw a nice patch of ground under a tree.

'Over there,' he pointed.

They all set to work and by nighttime the house of straw and the house of sticks were built but the house of bricks was only just beginning to rise above the ground. The first and second little pigs laughed, they thought their brother was really silly having to work so hard when they had finished."""

# %%
sentences = sent_tokenize(text)

# %%
type(sentences), len(sentences)
# Out:
# (list, 19)

# %%
sentences
# Out:
# ["Mrs Pig was very tired: 'Oh dear,' she said to her three little pigs, 'I can’t do this work anymore, I’m afraid you must leave home and make your own way in the world.'",
#  'So the three little pigs set off.',
#  'The first little pig met a man carrying a bundle of straw.',
#  "'Excuse me,' said the first little pig politely.",
#  "'Would you please sell some of your straw so I can make a house?'",
#  'The man readily agreed and the first little pig went off to find a good place to build his house.',
#  'The other little pigs carried on along the road and, soon, they met a man carrying a bundle of sticks.',
#  "'Excuse me,' said the little pig politely.",
#  "'Would you please sell me some sticks so I can build a house?'",
#  'The man readily agreed and the little pig said goodbye to his brother.',
#  "The third little pig didn’t think much of their ideas:\n\n'I’m going to build myself a much bigger, better, stronger house,' he thought, and he carried off down the road until he met a man with a cart load of bricks.",
#  "'Excuse me,' said the third little pig, as politely as his mother had taught him.",
#  "'Please can you sell me some bricks so I can build a house?'",
#  "'Of course,' said the man.",
#  "'Where would you like me to unload them?'",
#  'The third little pig looked around and saw a nice patch of ground under a tree.',
#  "'Over there,' he pointed.",
#  'They all set to work and by nighttime the house of straw and the house of sticks were built but the house of bricks was only just beginning to rise above the ground.',
#  'The first and second little pigs laughed, they thought their brother was really silly having to work so hard when they had finished.']

# %%
tokenized_sentences = [word_tokenize(sentence) for sentence in sentences]

tokenized_sentences
# Out:
# [['Mrs',
#   'Pig',
#   'was',
#   'very',
#   'tired',
#   ':',
#   "'Oh",
#   'dear',
#   ',',
#   "'",
#   'she',
#   'said',
#   'to',
#   'her',
#   'three',
#   'little',
#   'pigs',
#   ',',
#   "'",
#   'I',
#   'can',
#   '’',
#   't',
#   'do',
#   'this',
#   'work',
#   'anymore',
#   ',',
#   'I',
#   '’',
#   'm',
#   'afraid',
#   'you',
#   'must',
#   'leave',
#   'home',
#   'and',
#   'make',
#   'your',
#   'own',
#   'way',
#   'in',
#   'the',
#   'world',
#   '.',
#   "'"],
#  ['So', 'the', 'three', 'little', 'pigs', 'set', 'off', '.'],
#  ['The',
#   'first',
#   'little',
#   'pig',
#   'met',
#   'a',
#   'man',
#   'carrying',
#   'a',
#   'bundle',
#   'of',
#   'straw',
#   '.'],
#  ["'Excuse",
#   'me',
#   ',',
#   "'",
#   'said',
#   'the',
#   'first',
#   'little',
#   'pig',
#   'politely',
#   '.'],
#  ["'Would",
#   'you',
#   'please',
#   'sell',
#   'some',
#   'of',
#   'your',
#   'straw',
#   'so',
#   'I',
#   'can',
#   'make',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ['The',
#   'man',
#   'readily',
#   'agreed',
#   'and',
#   'the',
#   'first',
#   'little',
#   'pig',
#   'went',
#   'off',
#   'to',
#   'find',
#   'a',
#   'good',
#   'place',
#   'to',
#   'build',
#   'his',
#   'house',
#   '.'],
#  ['The',
#   'other',
#   'little',
#   'pigs',
#   'carried',
#   'on',
#   'along',
#   'the',
#   'road',
#   'and',
#   ',',
#   'soon',
#   ',',
#   'they',
#   'met',
#   'a',
#   'man',
#   'carrying',
#   'a',
#   'bundle',
#   'of',
#   'sticks',
#   '.'],
#  ["'Excuse", 'me', ',', "'", 'said', 'the', 'little', 'pig', 'politely', '.'],
#  ["'Would",
#   'you',
#   'please',
#   'sell',
#   'me',
#   'some',
#   'sticks',
#   'so',
#   'I',
#   'can',
#   'build',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ['The',
#   'man',
#   'readily',
#   'agreed',
#   'and',
#   'the',
#   'little',
#   'pig',
#   'said',
#   'goodbye',
#   'to',
#   'his',
#   'brother',
#   '.'],
#  ['The',
#   'third',
#   'little',
#   'pig',
#   'didn',
#   '’',
#   't',
#   'think',
#   'much',
#   'of',
#   'their',
#   'ideas',
#   ':',
#   "'",
#   'I',
#   '’',
#   'm',
#   'going',
#   'to',
#   'build',
#   'myself',
#   'a',
#   'much',
#   'bigger',
#   ',',
#   'better',
#   ',',
#   'stronger',
#   'house',
#   ',',
#   "'",
#   'he',
#   'thought',
#   ',',
#   'and',
#   'he',
#   'carried',
#   'off',
#   'down',
#   'the',
#   'road',
#   'until',
#   'he',
#   'met',
#   'a',
#   'man',
#   'with',
#   'a',
#   'cart',
#   'load',
#   'of',
#   'bricks',
#   '.'],
#  ["'Excuse",
#   'me',
#   ',',
#   "'",
#   'said',
#   'the',
#   'third',
#   'little',
#   'pig',
#   ',',
#   'as',
#   'politely',
#   'as',
#   'his',
#   'mother',
#   'had',
#   'taught',
#   'him',
#   '.'],
#  ["'Please",
#   'can',
#   'you',
#   'sell',
#   'me',
#   'some',
#   'bricks',
#   'so',
#   'I',
#   'can',
#   'build',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ["'Of", 'course', ',', "'", 'said', 'the', 'man', '.'],
#  ["'Where", 'would', 'you', 'like', 'me', 'to', 'unload', 'them', '?', "'"],
#  ['The',
#   'third',
#   'little',
#   'pig',
#   'looked',
#   'around',
#   'and',
#   'saw',
#   'a',
#   'nice',
#   'patch',
#   'of',
#   'ground',
#   'under',
#   'a',
#   'tree',
#   '.'],
#  ["'Over", 'there', ',', "'", 'he', 'pointed', '.'],
#  ['They',
#   'all',
#   'set',
#   'to',
#   'work',
#   'and',
#   'by',
#   'nighttime',
#   'the',
#   'house',
#   'of',
#   'straw',
#   'and',
#   'the',
#   'house',
#   'of',
#   'sticks',
#   'were',
#   'built',
#   'but',
#   'the',
#   'house',
#   'of',
#   'bricks',
#   'was',
#   'only',
#   'just',
#   'beginning',
#   'to',
#   'rise',
#   'above',
#   'the',
#   'ground',
#   '.'],
#  ['The',
#   'first',
#   'and',
#   'second',
#   'little',
#   'pigs',
#   'laughed',
#   ',',
#   'they',
#   'thought',
#   'their',
#   'brother',
#   'was',
#   'really',
#   'silly',
#   'having',
#   'to',
#   'work',
#   'so',
#   'hard',
#   'when',
#   'they',
#   'had',
#   'finished',
#   '.']]

# %%
import string
words = []

# Iterate over each sentence in the tokenized_sentences
for sentence in tokenized_sentences:
    # For each word in the sentence, check if it's not a punctuation mark
    for word in sentence:
        if word not in string.punctuation:
            # If it's not punctuation, add it to the words list
            words.append(word)

words
# Out:
# ['Mrs',
#  'Pig',
#  'was',
#  'very',
#  'tired',
#  "'Oh",
#  'dear',
#  'she',
#  'said',
#  'to',
#  'her',
#  'three',
#  'little',
#  'pigs',
#  'I',
#  'can',
#  '’',
#  't',
#  'do',
#  'this',
#  'work',
#  'anymore',
#  'I',
#  '’',
#  'm',
#  'afraid',
#  'you',
#  'must',
#  'leave',
#  'home',
#  'and',
#  'make',
#  'your',
#  'own',
#  'way',
#  'in',
#  'the',
#  'world',
#  'So',
#  'the',
#  'three',
#  'little',
#  'pigs',
#  'set',
#  'off',
#  'The',
#  'first',
#  'little',
#  'pig',
#  'met',
#  'a',
#  'man',
#  'carrying',
#  'a',
#  'bundle',
#  'of',
#  'straw',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'first',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'you',
#  'please',
#  'sell',
#  'some',
#  'of',
#  'your',
#  'straw',
#  'so',
#  'I',
#  'can',
#  'make',
#  'a',
#  'house',
#  'The',
#  'man',
#  'readily',
#  'agreed',
#  'and',
#  'the',
#  'first',
#  'little',
#  'pig',
#  'went',
#  'off',
#  'to',
#  'find',
#  'a',
#  'good',
#  'place',
#  'to',
#  'build',
#  'his',
#  'house',
#  'The',
#  'other',
#  'little',
#  'pigs',
#  'carried',
#  'on',
#  'along',
#  'the',
#  'road',
#  'and',
#  'soon',
#  'they',
#  'met',
#  'a',
#  'man',
#  'carrying',
#  'a',
#  'bundle',
#  'of',
#  'sticks',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'you',
#  'please',
#  'sell',
#  'me',
#  'some',
#  'sticks',
#  'so',
#  'I',
#  'can',
#  'build',
#  'a',
#  'house',
#  'The',
#  'man',
#  'readily',
#  'agreed',
#  'and',
#  'the',
#  'little',
#  'pig',
#  'said',
#  'goodbye',
#  'to',
#  'his',
#  'brother',
#  'The',
#  'third',
#  'little',
#  'pig',
#  'didn',
#  '’',
#  't',
#  'think',
#  'much',
#  'of',
#  'their',
#  'ideas',
#  'I',
#  '’',
#  'm',
#  'going',
#  'to',
#  'build',
#  'myself',
#  'a',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'house',
#  'he',
#  'thought',
#  'and',
#  'he',
#  'carried',
#  'off',
#  'down',
#  'the',
#  'road',
#  'until',
#  'he',
#  'met',
#  'a',
#  'man',
#  'with',
#  'a',
#  'cart',
#  'load',
#  'of',
#  'bricks',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'third',
#  'little',
#  'pig',
#  'as',
#  'politely',
#  'as',
#  'his',
#  'mother',
#  'had',
#  'taught',
#  'him',
#  "'Please",
#  'can',
#  'you',
#  'sell',
#  'me',
#  'some',
#  'bricks',
#  'so',
#  'I',
#  'can',
#  'build',
#  'a',
#  'house',
#  "'Of",
#  'course',
#  'said',
#  'the',
#  'man',
#  "'Where",
#  'would',
#  'you',
#  'like',
#  'me',
#  'to',
#  'unload',
#  'them',
#  'The',
#  'third',
#  'little',
#  'pig',
#  'looked',
#  'around',
#  'and',
#  'saw',
#  'a',
#  'nice',
#  'patch',
#  'of',
#  'ground',
#  'under',
#  'a',
#  'tree',
#  "'Over",
#  'there',
#  'he',
#  'pointed',
#  'They',
#  'all',
#  'set',
#  'to',
#  'work',
#  'and',
#  'by',
#  'nighttime',
#  'the',
#  'house',
#  'of',
#  'straw',
#  'and',
#  'the',
#  'house',
#  'of',
#  'sticks',
#  'were',
#  'built',
#  'but',
#  'the',
#  'house',
#  'of',
#  'bricks',
#  'was',
#  'only',
#  'just',
#  'beginning',
#  'to',
#  'rise',
#  'above',
#  'the',
#  'ground',
#  'The',
#  'first',
#  'and',
#  'second',
#  'little',
#  'pigs',
#  'laughed',
#  'they',
#  'thought',
#  'their',
#  'brother',
#  'was',
#  'really',
#  'silly',
#  'having',
#  'to',
#  'work',
#  'so',
#  'hard',
#  'when',
#  'they',
#  'had',
#  'finished']

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words("english"))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_words = [word for word in words if word.lower() not in stop_words]
filtered_words
# Out:
# ['Mrs',
#  'Pig',
#  'tired',
#  "'Oh",
#  'dear',
#  'said',
#  'three',
#  'little',
#  'pigs',
#  '’',
#  'work',
#  'anymore',
#  '’',
#  'afraid',
#  'must',
#  'leave',
#  'home',
#  'make',
#  'way',
#  'world',
#  'three',
#  'little',
#  'pigs',
#  'set',
#  'first',
#  'little',
#  'pig',
#  'met',
#  'man',
#  'carrying',
#  'bundle',
#  'straw',
#  "'Excuse",
#  'said',
#  'first',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'please',
#  'sell',
#  'straw',
#  'make',
#  'house',
#  'man',
#  'readily',
#  'agreed',
#  'first',
#  'little',
#  'pig',
#  'went',
#  'find',
#  'good',
#  'place',
#  'build',
#  'house',
#  'little',
#  'pigs',
#  'carried',
#  'along',
#  'road',
#  'soon',
#  'met',
#  'man',
#  'carrying',
#  'bundle',
#  'sticks',
#  "'Excuse",
#  'said',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'please',
#  'sell',
#  'sticks',
#  'build',
#  'house',
#  'man',
#  'readily',
#  'agreed',
#  'little',
#  'pig',
#  'said',
#  'goodbye',
#  'brother',
#  'third',
#  'little',
#  'pig',
#  '’',
#  'think',
#  'much',
#  'ideas',
#  '’',
#  'going',
#  'build',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'house',
#  'thought',
#  'carried',
#  'road',
#  'met',
#  'man',
#  'cart',
#  'load',
#  'bricks',
#  "'Excuse",
#  'said',
#  'third',
#  'little',
#  'pig',
#  'politely',
#  'mother',
#  'taught',
#  "'Please",
#  'sell',
#  'bricks',
#  'build',
#  'house',
#  "'Of",
#  'course',
#  'said',
#  'man',
#  "'Where",
#  'would',
#  'like',
#  'unload',
#  'third',
#  'little',
#  'pig',
#  'looked',
#  'around',
#  'saw',
#  'nice',
#  'patch',
#  'ground',
#  'tree',
#  "'Over",
#  'pointed',
#  'set',
#  'work',
#  'nighttime',
#  'house',
#  'straw',
#  'house',
#  'sticks',
#  'built',
#  'house',
#  'bricks',
#  'beginning',
#  'rise',
#  'ground',
#  'first',
#  'second',
#  'little',
#  'pigs',
#  'laughed',
#  'thought',
#  'brother',
#  'really',
#  'silly',
#  'work',
#  'hard',
#  'finished']

# %% [markdown]
# # Завдання 2
#
#  * Зробіть стемінг слів
#  * Зробіть лематизацію слів
#  * Створіть `pandas.DataFrame` зі словами, що мають різний результат при стемінгу та лематизації. Має бути 3 стовпчика:
#   * оригінальне сово
#   * результат стемінгу
#   * результат лематизації

# %%
import pandas as pd
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]
stemmed_words
# Out:
# ['mr',
#  'pig',
#  'tire',
#  "'oh",
#  'dear',
#  'said',
#  'three',
#  'littl',
#  'pig',
#  '’',
#  'work',
#  'anymor',
#  '’',
#  'afraid',
#  'must',
#  'leav',
#  'home',
#  'make',
#  'way',
#  'world',
#  'three',
#  'littl',
#  'pig',
#  'set',
#  'first',
#  'littl',
#  'pig',
#  'met',
#  'man',
#  'carri',
#  'bundl',
#  'straw',
#  "'excus",
#  'said',
#  'first',
#  'littl',
#  'pig',
#  'polit',
#  "'would",
#  'pleas',
#  'sell',
#  'straw',
#  'make',
#  'hous',
#  'man',
#  'readili',
#  'agre',
#  'first',
#  'littl',
#  'pig',
#  'went',
#  'find',
#  'good',
#  'place',
#  'build',
#  'hous',
#  'littl',
#  'pig',
#  'carri',
#  'along',
#  'road',
#  'soon',
#  'met',
#  'man',
#  'carri',
#  'bundl',
#  'stick',
#  "'excus",
#  'said',
#  'littl',
#  'pig',
#  'polit',
#  "'would",
#  'pleas',
#  'sell',
#  'stick',
#  'build',
#  'hous',
#  'man',
#  'readili',
#  'agre',
#  'littl',
#  'pig',
#  'said',
#  'goodby',
#  'brother',
#  'third',
#  'littl',
#  'pig',
#  '’',
#  'think',
#  'much',
#  'idea',
#  '’',
#  'go',
#  'build',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'hous',
#  'thought',
#  'carri',
#  'road',
#  'met',
#  'man',
#  'cart',
#  'load',
#  'brick',
#  "'excus",
#  'said',
#  'third',
#  'littl',
#  'pig',
#  'polit',
#  'mother',
#  'taught',
#  "'pleas",
#  'sell',
#  'brick',
#  'build',
#  'hous',
#  "'of",
#  'cours',
#  'said',
#  'man',
#  "'where",
#  'would',
#  'like',
#  'unload',
#  'third',
#  'littl',
#  'pig',
#  'look',
#  'around',
#  'saw',
#  'nice',
#  'patch',
#  'ground',
#  'tree',
#  "'over",
#  'point',
#  'set',
#  'work',
#  'nighttim',
#  'hous',
#  'straw',
#  'hous',
#  'stick',
#  'built',
#  'hous',
#  'brick',
#  'begin',
#  'rise',
#  'ground',
#  'first',
#  'second',
#  'littl',
#  'pig',
#  'laugh',
#  'thought',
#  'brother',
#  'realli',
#  'silli',
#  'work',
#  'hard',
#  'finish']

# %%
df = pd.DataFrame()
filtered_words = [word.lower() for word in filtered_words]

# %%
df['word'] = filtered_words
df
# Out:
#          word
# 0         mrs
# 1         pig
# 2       tired
# 3         'oh
# 4        dear
# ..        ...
# 162    really
# 163     silly
# 164      work
# 165      hard
# 166  finished
#
# [167 rows x 1 columns]

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]
df['stem'] = stemmed_words

df
# Out:
#          word    stem
# 0         mrs      mr
# 1         pig     pig
# 2       tired    tire
# 3         'oh     'oh
# 4        dear    dear
# ..        ...     ...
# 162    really  realli
# 163     silly   silli
# 164      work    work
# 165      hard    hard
# 166  finished  finish
#
# [167 rows x 2 columns]

# %%
nltk.download('wordnet')
lematizer = WordNetLemmatizer()

lemmas = [lematizer.lemmatize(word) for word in filtered_words]
df['lemma'] = lemmas
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#          word    stem     lemma
# 0         mrs      mr        mr
# 1         pig     pig       pig
# 2       tired    tire     tired
# 3         'oh     'oh       'oh
# 4        dear    dear      dear
# ..        ...     ...       ...
# 162    really  realli    really
# 163     silly   silli     silly
# 164      work    work      work
# 165      hard    hard      hard
# 166  finished  finish  finished
#
# [167 rows x 3 columns]

# %%
mask = df['stem'] != df['lemma']
df[mask]
# Out:
#           word      stem      lemma
# 2        tired      tire      tired
# 7       little     littl     little
# 11     anymore    anymor    anymore
# 15       leave      leav      leave
# 21      little     littl     little
# 25      little     littl     little
# 29    carrying     carri   carrying
# 30      bundle     bundl     bundle
# 32     'excuse    'excus    'excuse
# 35      little     littl     little
# 37    politely     polit   politely
# 39      please     pleas     please
# 43       house      hous      house
# 45     readily   readili    readily
# 46      agreed      agre     agreed
# 48      little     littl     little
# 55       house      hous      house
# 56      little     littl     little
# 58     carried     carri    carried
# 64    carrying     carri   carrying
# 65      bundle     bundl     bundle
# 67     'excuse    'excus    'excuse
# 69      little     littl     little
# 71    politely     polit   politely
# 73      please     pleas     please
# 77       house      hous      house
# 79     readily   readili    readily
# 80      agreed      agre     agreed
# 81      little     littl     little
# 84     goodbye    goodby    goodbye
# 87      little     littl     little
# 94       going        go      going
# 100      house      hous      house
# 102    carried     carri    carried
# 109    'excuse    'excus    'excuse
# 112     little     littl     little
# 114   politely     polit   politely
# 117    'please    'pleas    'please
# 121      house      hous      house
# 123     course     cours     course
# 131     little     littl     little
# 133     looked      look     looked
# 141    pointed     point    pointed
# 144  nighttime  nighttim  nighttime
# 145      house      hous      house
# 147      house      hous      house
# 150      house      hous      house
# 152  beginning     begin  beginning
# 157     little     littl     little
# 159    laughed     laugh    laughed
# 162     really    realli     really
# 163      silly     silli      silly
# 166   finished    finish   finished

# %% [markdown]
# # Завдання 3
# Виділіть фрази за такими шаблонами:
#   * прикметник + іменник
#   * (хоча б 1 прикметник) + іменник
#   * (прислівник + дієслово) АБО (дієслово + прислівник)

# %%
# text = """Mrs Pig was very tired: 'Oh dear,' she said to her three little pigs, 'I can’t do this work anymore, I’m afraid you must leave home and make your own way in the world.' So the three little pigs set off.

# The first little pig met a man carrying a bundle of straw.

# 'Excuse me,' said the first little pig politely. 'Would you please sell some of your straw so I can make a house?'

# The man readily agreed and the first little pig went off to find a good place to build his house.

# The other little pigs carried on along the road and, soon, they met a man carrying a bundle of sticks.

# 'Excuse me,' said the little pig politely. 'Would you please sell me some sticks so I can build a house?'

# The man readily agreed and the little pig said goodbye to his brother.

# The third little pig didn’t think much of their ideas:

# 'I’m going to build myself a much bigger, better, stronger house,' he thought, and he carried off down the road until he met a man with a cart load of bricks.

# 'Excuse me,' said the third little pig, as politely as his mother had taught him. 'Please can you sell me some bricks so I can build a house?'

# 'Of course,' said the man. 'Where would you like me to unload them?'

# The third little pig looked around and saw a nice patch of ground under a tree.

# 'Over there,' he pointed.

# They all set to work and by nighttime the house of straw and the house of sticks were built but the house of bricks was only just beginning to rise above the ground. The first and second little pigs laughed, they thought their brother was really silly having to work so hard when they had finished."""


import nltk
from nltk import word_tokenize, pos_tag
from nltk.chunk import RegexpParser
import contractions  # pip install contractions
import re

def extract_phrases(text):
    # Токенізація та частиномовне тегування
    tokens = word_tokenize(text)
    tags = pos_tag(tokens)

    # Визначення граматики
    grammar = r"""
        ADJ_NN: {<JJ><NN.*>}                    # Прикметник + Іменник
        ADJ_PLUS_NN: {<JJ>+<NN.*>}             # (Хоча б 1 прикметник) + Іменник
        ADV_VB: {<RB><VB.*> | <VB.*><RB>}      # (Прислівник + Дієслово) АБО (Дієслово + Прислівник)
    """

    # Створення парсера
    chunk_parser = RegexpParser(grammar)

    # Розбір тегованого тексту
    tree = chunk_parser.parse(tags)

    # Вибір знайдених фраз
    phrases = {"ADJ_NN": [], "ADJ_PLUS_NN": [], "ADV_VB": []}
    for subtree in tree.subtrees():
        if subtree.label() in phrases:
            # Формування фрази
            phrase = " ".join(word for word, tag in subtree.leaves())
            # Фільтруємо некоректні фрази
            if all(word.isalpha() for word in phrase.split()):  # Лише алфавітні слова
                phrases[subtree.label()].append(phrase)

    return phrases

result = extract_phrases(text)
print("Прикметник + Іменник:", result["ADJ_NN"])
print("Хоча б 1 прикметник + Іменник:", result["ADJ_PLUS_NN"])
print("Прислівник + Дієслово або Дієслово + Прислівник:", result["ADV_VB"])
# Out:
# Прикметник + Іменник: ['little pigs', 'own way', 'little pigs', 'little pig', 'little pig', 'little pig', 'good place', 'little pigs', 'little pig', 'little pig', 'little pig', 'cart load', 'little pig', 'little pig', 'nice patch', 'little pigs']
# Хоча б 1 прикметник + Іменник: []
# Прислівник + Дієслово або Дієслово + Прислівник: ['was very', 'readily agreed', 'readily agreed', 'think much', 'was only', 'just beginning', 'was really', 'silly having', 'work so']
