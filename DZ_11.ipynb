# %% [markdown]
# <a href="https://colab.research.google.com/github/alonacode/AI/blob/main/DZ_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ваша задача методом градієнтного спуску знайти коефіцієнти для задачі регресії. Обираємо метод лінійної регресії та дані про діаманти

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/diamonds.csv",
                 index_col=0)

df.head()
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335

# %%
df.shape
# Out:
# (53940, 2)

# %%
import torch

# %%
# створіть тензори без градієнтів
y = y = torch.tensor(df['price'].values, dtype=torch.float32, requires_grad=False)  # для стовпчика price
x = torch.tensor(df['carat'].values, dtype=torch.float32, requires_grad=False)   # для стовпчика carat

print("Ціни (y):", y)
print("Карати (x):", x)
# Out:
# Ціни (y): tensor([ 326.,  326.,  327.,  ..., 2757., 2757., 2757.])
# Карати (x): tensor([0.2300, 0.2100, 0.2300,  ..., 0.7000, 0.8600, 0.7500])

# %%
# створіть тензори з градієнтом, оберіть довільне початкове значення
coef = torch.randn(1, requires_grad=True)
intercept = torch.tensor(1.0, requires_grad=True)

# вкажіть навчальний крок
learning_rate = 0.01

# визначення алгоритму


# основний цикл
for t in range(4000):
  # обрахуйте прогноз моделі за формулою лінійної регресії
  y_pred = coef * x + intercept
  # обрахуйте метрику середньо квадратичного

  # не використовуйте sklearn, лише функції torch
  # див torch.mean
  loss = torch.mean((y_pred - y) ** 2)
  # не використовуйте sklearn, лише функ
  # виведіть значення метрики для кожного сотого кроку
  if t % 100 == 0:
        print(f"Крок {t}: Втрата = {loss.item()}")

    # обрахуйте градієнти по метриці
  loss.backward()

  # обрахуйте градієнти по метриці

  # градієнтний спуск

  with torch.no_grad():
        coef -= learning_rate * coef.grad
        intercept -= learning_rate * intercept.grad

        # Обнуляємо градієнти
        coef.grad.zero_()
        intercept.grad.zero_()
# Out:
# Крок 0: Втрата = 31375114.0
# Крок 100: Втрата = 6464904.0
# Крок 200: Втрата = 4805186.0
# Крок 300: Втрата = 3829550.75
# Крок 400: Втрата = 3249341.25
# Крок 500: Втрата = 2904283.0
# Крок 600: Втрата = 2699073.75
# Крок 700: Втрата = 2577034.25
# Крок 800: Втрата = 2504454.75
# Крок 900: Втрата = 2461291.75
# Крок 1000: Втрата = 2435622.0
# Крок 1100: Втрата = 2420356.0
# Крок 1200: Втрата = 2411277.5
# Крок 1300: Втрата = 2405878.0
# Крок 1400: Втрата = 2402666.75
# Крок 1500: Втрата = 2400757.25
# Крок 1600: Втрата = 2399621.5
# Крок 1700: Втрата = 2398946.25
# Крок 1800: Втрата = 2398544.5
# Крок 1900: Втрата = 2398305.5
# Крок 2000: Втрата = 2398163.5
# Крок 2100: Втрата = 2398079.0
# Крок 2200: Втрата = 2398029.0
# Крок 2300: Втрата = 2397999.0
# Крок 2400: Втрата = 2397981.25
# Крок 2500: Втрата = 2397970.5
# Крок 2600: Втрата = 2397964.25
# Крок 2700: Втрата = 2397960.5
# Крок 2800: Втрата = 2397958.5
# Крок 2900: Втрата = 2397957.0
# Крок 3000: Втрата = 2397956.25
# Крок 3100: Втрата = 2397955.75
# Крок 3200: Втрата = 2397955.5
# Крок 3300: Втрата = 2397955.5
# Крок 3400: Втрата = 2397955.25
# Крок 3500: Втрата = 2397955.25
# Крок 3600: Втрата = 2397955.25
# Крок 3700: Втрата = 2397955.25
# Крок 3800: Втрата = 2397955.0
# Крок 3900: Втрата = 2397955.25

# %% [markdown]
# # Результат

# %%
coef.item(), intercept.item()
# Out:
# (7756.24072265625, -2256.19482421875)

# %% [markdown]
# # Порівняйте результат з sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
X_train = df.drop(columns=['price'])
y_train = df['price']
# тренування
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0], model.intercept_
# Out:
# (7756.425617968435, -2256.360580045403)
